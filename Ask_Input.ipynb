# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Class-and-Objects/blob/main/Ask_Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name?\n")
age = input("Whhat is your age?\n")
print("Hello!"+ " Welcome "+ name+ "!" +"In order to continue, you must be 21+ or what is your age ="+age + " ?")
# Out:
# What is your name?
# PK
# Whhat is your age?
# 19
# Hello! Welcome PK!In order to continue, you must be 21+ or what is your age =19 ?

# %%
mood= input("How are you feeling today? ")
print("No matter what, everything will be fine.")
# Out:
# How are you feeling today? Good
# No matter what everything will be fine.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import seaborn
import matplotlib as plt
import html
import datascience

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/2022_FIFA_World_Cup")

# %%
print(df)
# Out:
# [    0                                                  1
# 0 NaN  This article documents a current FIFA World Cu...,    كأس العالم لكرة القدم 2022Kaʾs al-ʿālam li-kurat al-qadam 2022  \
# 0   .mw-parser-output .script-arabic{font-family:"...
# 1                                  Tournament details
# 2                                        Host country
# 3                                               Dates
# 4                                               Teams
# 5                                            Venue(s)
# 6                               Tournament statistics
# 7                                      Matches played
# 8                                        Goals scored
# 9                                          Attendance
# 10                                      Top scorer(s)
# 11  ← 2018 2026 → All statistics correct as of 6 D...
#
#    كأس العالم لكرة القدم 2022Kaʾs al-ʿālam li-kurat al-qadam 2022.1
# 0   .mw-parser-output .script-arabic{font-family:"...
# ...
